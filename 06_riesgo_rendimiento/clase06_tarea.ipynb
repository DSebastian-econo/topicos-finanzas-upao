# %% [markdown]
# # Semana 6: Tarea
#
# **Tu empresa entra a un portafolio** (la misma de las semanas anteriores)
#
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JonathanRosasV/topicos-finanzas-upao/blob/main/06_riesgo_rendimiento/clase06_tarea.ipynb)
#
# **Entrega: hasta el lunes de la semana siguiente, vía `git commit` + `push` en tu fork** (`06_riesgo_rendimiento/clase06_tarea.ipynb`)
#
# Total: 20 puntos (18 de contenido y 2 de forma). En la unidad 1 valoraste tu empresa sola. Desde hoy la miras como la mira un gestor: por lo que le aporta a un portafolio. El universo que armes aquí lo reutilizarás en la tarea de Markowitz.

# %% [markdown]
# ## Parte 1: tu universo y sus estadísticos (4 pts)
#
# Arma un universo de 6 activos: tu empresa más 5 acciones que elijas con un criterio declarado en una celda de texto (busca variedad de sector y de país, no cinco empresas parecidas a la tuya). Descarga 5 años de precios mensuales ajustados, lleva todo a una sola moneda si mezclas mercados, y reporta para cada activo el retorno medio y la volatilidad anualizados. Cierra con el mapa riesgo-retorno y una oración: ¿dónde cae tu empresa respecto de las demás?

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from utils.finanzas import (retornos, portafolio_dos_activos, peso_minima_varianza,
                            riesgo_portafolio, riesgo_equiponderado)

MI_EMPRESA = ""     # tu empresa
OTRAS = []          # 5 tickers, criterio declarado arriba

# TU CODIGO AQUI: precios, retornos mensuales, tabla anualizada y mapa riesgo-retorno

# %% [markdown]
# ## Parte 2: correlaciones (4 pts)
#
# Calcula la matriz de correlaciones de tu universo y muéstrala como mapa de calor. Identifica el activo **menos** correlacionado con tu empresa y el **más** correlacionado, y explica en dos o tres oraciones por qué tiene sentido económico (sector, país, materia prima, moneda). Si algo no tiene sentido, dilo: también es una respuesta válida.

# %%
# TU CODIGO AQUI: matriz de correlaciones, mapa de calor, el menos y el mas correlacionado con tu empresa

# %% [markdown]
# ## Parte 3: tu empresa y su mejor pareja (4 pts)
#
# Con tu empresa y el activo menos correlacionado de la parte 2: grafica la curva de todas las mezclas en el plano riesgo-retorno (con la recta de $\rho = 1$ como referencia), calcula el portafolio de mínima varianza (pesos, retorno y volatilidad) y responde: ¿ese portafolio tiene menos riesgo que el menos volátil de los dos activos por separado? ¿Cuántos puntos de volatilidad desaparecen en la mezcla 50/50 respecto del promedio ponderado?

# %%
# TU CODIGO AQUI: curva de dos activos, minima varianza y beneficio de diversificacion del 50/50

# %% [markdown]
# ## Parte 4: el efecto diversificación en tu universo (4 pts)
#
# Arma el portafolio de pesos iguales con tus 6 activos y compara su volatilidad contra (a) la de tu empresa sola y (b) el promedio de las volatilidades individuales. Luego calcula la covarianza promedio de tu universo y el piso sistemático que implica ($\sqrt{\overline{cov}}$). Cierra con un párrafo: ¿cuánto riesgo de tu empresa era diversificable?, ¿qué tan lejos está tu portafolio de 6 activos de su piso?, ¿qué le dirías a alguien que tiene todos sus ahorros en una sola acción?

# %%
# TU CODIGO AQUI: portafolio de pesos iguales, comparaciones y piso sistematico

# %% [markdown]
# ## Parte 5: ítems tipo CFA (2 pts, 0.5 c/u)
#
# **1.** Compras una acción a 40, cobras un dividendo de 2 y la vendes a 42 al cabo de un año. Tu retorno del periodo (HPR) es:
#
# A. 5.0%. B. 9.5%. C. 10.0%.
#
# **2.** La covarianza entre dos activos es 0.0120 y sus desviaciones estándar son 0.20 y 0.15. Su correlación es:
#
# A. 0.03. B. 0.40. C. 2.50.
#
# **3.** Un activo tiene retorno mensual medio de 1.5% y desviación estándar mensual de 5%. Su volatilidad anualizada es la más cercana a:
#
# A. 17.3%. B. 18.0%. C. 60.0%.
#
# **4.** Según la lógica de la diversificación, el riesgo por el que el mercado paga una prima es:
#
# A. el riesgo total del activo. B. el riesgo idiosincrático. C. el riesgo sistemático.
#
# **Respuestas:**
#
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
#
# **Recuerda:** `Kernel  Restart & Run All` antes de entregar, y luego:
#
# ```bash
# git add 06_riesgo_rendimiento/clase06_tarea.ipynb
# git commit -m "Tarea semana 6"
# git push
# ```
