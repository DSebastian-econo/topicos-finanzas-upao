# %% [markdown]
# # Semana 7: Tarea
#
# **La frontera eficiente de tu universo** (los mismos seis activos de la tarea 6)
#
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JonathanRosasV/topicos-finanzas-upao/blob/main/07_markowitz_frontera/clase07_tarea.ipynb)
#
# **Entrega: hasta el lunes de la semana siguiente, vía `git commit` + `push` en tu fork** (`07_markowitz_frontera/clase07_tarea.ipynb`)
#
# Total: 20 puntos (18 de contenido y 2 de forma). Esta tarea es más corta que las anteriores porque la prioridad de la semana es el examen parcial (miércoles 21/10). Reutiliza el universo y el código de datos de tu tarea 6.

# %% [markdown]
# ## Parte 1: los insumos (3 pts)
#
# Con tu universo de 6 activos (tu empresa más los 5 de la tarea 6): retornos mensuales de 5 años en una sola moneda, $\mu$ y $\Sigma$ anualizados, y una tasa libre de riesgo **consistente con la moneda de tus retornos** (declara cuál usas, de dónde sale y por qué es consistente). Muestra la tabla de cada activo con su retorno medio, su volatilidad y su ratio de Sharpe.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from utils.finanzas import (retornos, riesgo_portafolio, min_varianza,
                            portafolio_tangente, frontera_eficiente)

MI_EMPRESA = ""     # tu empresa
OTRAS = []          # los 5 tickers de tu tarea 6

# TU CODIGO AQUI: precios, retornos, mu, cov, rf y tabla con el Sharpe de cada activo

# %% [markdown]
# ## Parte 2: la frontera, el PMV y el tangente (6 pts)
#
# Sin ventas en corto: calcula el portafolio de mínima varianza, el tangente y la frontera eficiente. Haz el gráfico riesgo-retorno con los 6 activos, la frontera, el PMV, el tangente y la CAL. Reporta para el PMV y el tangente: pesos, retorno esperado, volatilidad y Sharpe. Responde: ¿cuánto pesa tu empresa en cada uno y por qué crees que el optimizador le dio ese peso (mira su Sharpe y sus correlaciones)?

# %%
# TU CODIGO AQUI: min_varianza, portafolio_tangente, frontera_eficiente y grafico con la CAL

# %% [markdown]
# ## Parte 3: tu cliente (3 pts)
#
# Un cliente con aversión al riesgo $A = 4$ te pide una recomendación. Calcula la fracción óptima $y^{*}$ en tu portafolio tangente, y el retorno esperado y la volatilidad de su cartera completa. ¿Presta o se endeuda? Repite con $A = 2$. Escribe en dos oraciones la recomendación que le darías al primero, en lenguaje que un cliente entienda.

# %%
# TU CODIGO AQUI: y*, retorno y riesgo de la cartera completa para A = 4 y A = 2

# %% [markdown]
# ## Parte 4: la prueba de estabilidad (4 pts)
#
# Repite el bootstrap de la práctica con tu universo (al menos 200 remuestreos): diagrama de cajas de los pesos del tangente y del PMV, y la rotación media de cada uno. Luego impón un tope de 25% por activo al tangente (si tu mayor peso ya era menor que 25%, baja el tope hasta que restrinja, y dilo) y compara su Sharpe y su mayor peso contra el tangente libre. Cierra con un párrafo: ¿le presentarías tu tangente libre a un comité?, ¿qué portafolio recomendarías finalmente y por qué?

# %%
# TU CODIGO AQUI: bootstrap de pesos, tangente con w_max=0.25 y comparacion

# %% [markdown]
# ## Parte 5: ítems tipo CFA (2 pts, 0.5 c/u)
#
# **1.** Un portafolio tiene $E(R) = 11\%$ y $\sigma = 14\%$, y la tasa libre de riesgo es 4%. Su ratio de Sharpe es:
#
# A. 0.29. B. 0.50. C. 0.79.
#
# **2.** Respecto de la frontera eficiente, el portafolio de mínima varianza global:
#
# A. está por debajo de ella. B. es su punto de inicio, en el extremo izquierdo. C. es el de mayor ratio de Sharpe.
#
# **3.** Según la separación en dos fondos, dos inversionistas con distinta aversión al riesgo y las mismas expectativas tendrán:
#
# A. distintos portafolios riesgosos. B. el mismo portafolio riesgoso, en distintas proporciones con el activo libre de riesgo. C. exactamente la misma cartera completa.
#
# **4.** La crítica práctica más importante a la optimización media-varianza es que sus pesos son muy sensibles a:
#
# A. los retornos esperados estimados. B. el número de decimales. C. la tasa libre de riesgo.
#
# **Respuestas:**
#
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
#
# **Recuerda:** `Kernel  Restart & Run All` antes de entregar, y luego:
#
# ```bash
# git add 07_markowitz_frontera/clase07_tarea.ipynb
# git commit -m "Tarea semana 7"
# git push
# ```
