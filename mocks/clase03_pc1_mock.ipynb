# %% [markdown]
# # PC1: Examen de práctica (mock)
#
# **Tópicos de Finanzas Avanzadas (ECON-421, UPAO 2026-20)**
#
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JonathanRosasV/topicos-finanzas-upao/blob/main/mocks/clase03_pc1_mock.ipynb)
#
# Este es un examen de práctica para prepararte para la PC1 del miércoles 16 de setiembre. Tiene el mismo formato y las mismas reglas que el examen real, con algo más de extensión para que sirva de repaso completo de las semanas 1 a 3. El solucionario está en el repositorio (`clase03_pc1_mock_solucionario.ipynb`): intenta resolver todo antes de mirarlo, que ahí está el aprendizaje.
#
# ## Las reglas del examen real (practícalas desde ya)
#
# La PC1 es con **libro abierto de verdad**: internet, apuntes, el repositorio, Python y cualquier IA. A cambio:
#
# 1. **Las respuestas escritas van con tus palabras y aplicadas a tu empresa** (la de tus tareas). Una respuesta genérica pegada de una IA, correcta pero que podría ser de cualquier alumno, vale la mitad.
# 2. **El trabajo es individual.** Puedes conversar con una IA, no con tus compañeros.
#
# Entrega del examen real: completar el notebook, `Kernel  Restart & Run All`, exportar a PDF desde el navegador (en Colab: Archivo, Imprimir, Guardar como PDF) y subirlo a Canvas antes del fin de la sesión. Practica la exportación con este mock para que el día del examen no sea tu primera vez.

# %% [markdown]
# ## Parte 1: los conceptos con tus palabras (6 preguntas)
#
# En el examen real serán 4 preguntas de este estilo. Responde cada una en máximo dos oraciones, con tus palabras y usando tu empresa como ejemplo donde aplique.
#
# **1.1** Tu estimado del valor de una acción es 60 y el precio de mercado es 50. ¿Por qué esos 10 de diferencia no son una ganancia asegurada? Nombra las dos cosas que se mezclan en esa diferencia.
#
# *Tu respuesta:*
#
# **1.2** Explica por qué dos analistas serios pueden llegar a tasas de descuento distintas para la misma empresa, sin que ninguno esté "equivocado". Nombra dos insumos donde legítimamente pueden diferir.
#
# *Tu respuesta:*
#
# **1.3** El gerente de tu empresa presume de utilidades récord, pero la caja de la empresa cayó en el año. Da dos mecanismos concretos que pueden explicarlo al mismo tiempo.
#
# *Tu respuesta:*
#
# **1.4** ¿Por qué al construir el FCFF desde la utilidad neta se devuelve el interés multiplicado por (1 - t) y no el interés completo? ¿Qué pasaría con tu FCFF si devolvieras el interés completo?
#
# *Tu respuesta:*
#
# **1.5** El beta de tu regresión salió 1.6. ¿Por qué el ajuste de Blume lo acerca a 1 antes de usarlo en el CAPM? Da las dos razones (una económica, una estadística).
#
# *Tu respuesta:*
#
# **1.6** Enuncia la regla de consistencia completa (flujo, tasa, resultado) y explica en una oración qué pasaría con tu valoración del equity si descontaras el FCFE al WACC.
#
# *Tu respuesta:*

# %% [markdown]
# ## Parte 2: encuentra los errores
#
# En el examen real el caso tendrá 4 errores; este tiene **cinco**, y cubre más temario (semanas 2 y 3 juntas).
#
# Un practicante valoró a la empresa Sierra Azul SAC. Sus datos de partida son correctos:
#
# EBIT = 60, t = 30 por ciento, depreciación = 15, capex = 20, incremento del capital de trabajo = 5, gasto por intereses = 10, endeudamiento neto = 0. Capitalización bursátil = 400, deuda a valor de mercado = 200 (en libros: patrimonio 250, deuda 250). Beta = 1.3, ERP = 5 por ciento, Kd = 6 por ciento. Treasury a 10 años: 4.5 por ciento; Treasury a 3 meses: 3.8 por ciento. La empresa tiene 100 acciones y cotiza a 4.00.
#
# > **Paso 1.** Como la tasa de 3 meses es más "libre de riesgo", uso rf = 3.8 por ciento: Ke = 3.8 + 1.3 x 5 = **10.3 por ciento**.
# >
# > **Paso 2.** Con los valores del balance auditado: WACC = 0.5 x 10.3 + 0.5 x 6 x (1 - 0.30) = **7.25 por ciento**.
# >
# > **Paso 3.** Utilidad neta = (60 - 10) x 0.70 = 35. FCFF = NI + Dep + Int - Capex - WCInv = 35 + 15 + 10 - 20 - 5 = **35**.
# >
# > **Paso 4.** La empresa creció 8 por ciento estos años, así que uso g = 8 por ciento a perpetuidad. Valor de la firma = FCFF x (1+g) / (Ke - g) = 35 x 1.08 / (0.103 - 0.08) = **1,643.5**. La acción está regaladísima.
#
# Identifica los **cinco errores conceptuales**, explica cada uno en una oración, y recalcula todo corregido usando g = 3 por ciento: Ke, WACC, FCFF y valor por acción. Concluye con un veredicto sobre la acción.
#
# *Errores y explicaciones:*
#
# 1.
# 2.
# 3.
# 4.
# 5.

# %%
# Recalculo corregido (puedes usar utils/finanzas.py si trabajas en tu fork)

# TU CODIGO AQUI

# %% [markdown]
# *Veredicto:*

# %% [markdown]
# ## Parte 3: tu empresa
#
# Igual que en el examen real, con tu empresa de las tareas.
#
# **3.1** Calcula el FCFF del último año disponible por DOS rutas (EBIT y CFO) y muestra los insumos. Comenta en una oración por qué no coinciden exactamente. (En el examen real se pedirá una sola ruta; practicar las dos te deja mejor parado.)

# %%
# TU CODIGO AQUI: FCFF por ruta EBIT y por ruta CFO

# %% [markdown]
# **3.2** Reporta el beta, el error estándar y el R2 de tu regresión de la tarea 2, e interpreta cada uno en una oración.
#
# *Tu respuesta:*
#
# **3.3** Para valorar el equity de tu empresa, ¿FCFF o FCFE? Justifica mirando sus datos reales (trayectoria de la deuda, signo del FCFE).
#
# *Tu respuesta:*
#
# **3.4** El interés que pagó tu empresa el año pasado: ¿a qué financista fue y por qué NO se resta al calcular el FCFF?
#
# *Tu respuesta:*

# %% [markdown]
# ## Parte 4: tú y tu IA
#
# Igual que en el examen real.
#
# **4.1** Pega el prompt más útil que le diste a una IA mientras resolvías este mock (o las tareas).
#
# *Prompt:*
#
# **4.2** Señala algo que la IA respondió de forma incompleta, genérica o mal, y cómo lo detectaste o corregiste. Si todo estuvo perfecto, explica cómo lo verificaste.
#
# *Tu respuesta:*

# %% [markdown]
# ## Parte 5: ítems rápidos de repaso (solo en el mock)
#
# Seis ítems adicionales que no estarán en el examen real con este formato, pero cubren el temario completo. Respóndelos sin calculadora primero; luego verifica con Python.
#
# **5.1** Un proyecto con flujos convencionales tiene TIR de 15 por ciento. Si la tasa exigida es 12 por ciento, su VPN es: A. positivo. B. cero. C. negativo.
#
# **5.2** Beta de regresión 1.6. El beta ajustado de Blume es: A. 1.30. B. 1.40. C. 1.60.
#
# **5.3** Un bono paga cupón de 7 por ciento y la tasa exigida es 7 por ciento. Su precio es: A. mayor al nominal. B. igual al nominal. C. menor al nominal.
#
# **5.4** FCFF = 90, interés = 12, t = 25 por ciento, endeudamiento neto = -20 (amortizó). El FCFE es: A. 61. B. 78. C. 101.
#
# **5.5** Los pesos del WACC deben reflejar: A. el balance auditado. B. la estructura de capital a valor de mercado (idealmente la objetivo). C. el promedio histórico contable.
#
# **5.6** Una empresa con ROIC de 15 por ciento y WACC de 9 por ciento acelera su crecimiento reinvirtiendo más. Su valor: A. sube. B. baja. C. no cambia.
#
# **Respuestas:**
#
# 5.1
# 5.2
# 5.3
# 5.4
# 5.5
# 5.6

# %% [markdown]
# ---
#
# Cuando termines: compara contra el solucionario, anota los errores que cometiste (esos son exactamente lo que debes repasar), y practica la exportación a PDF. Nos vemos en la PC1.
