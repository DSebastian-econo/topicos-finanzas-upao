# %% [markdown]
# # Semana 5: Tarea
#
# **El panel de comparables de tu empresa** (la misma de las semanas anteriores)
#
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JonathanRosasV/topicos-finanzas-upao/blob/main/05_multiplos_comparables/clase05_tarea.ipynb)
#
# **Entrega: hasta el lunes de la semana siguiente, vía `git commit` + `push` en tu fork** (`05_multiplos_comparables/clase05_tarea.ipynb`)
#
# Total: 20 puntos (18 de contenido y 2 de forma). Esta tarea produce la sección de "método de contraste" de tu TR1: hazla pensando en reutilizarla.

# %% [markdown]
# ## Parte 1: el panel (5 pts)
#
# Elige entre 4 y 6 comparables de tu empresa y declara tus criterios de selección en una celda de texto (sector y modelo de negocio, tamaño, geografía). Descarga los datos y construye la tabla de múltiplos (EV/EBITDA, P/E y P/B como mínimo), todos trailing y con definiciones consistentes. Reporta la mediana del grupo excluyendo a tu empresa.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
import numpy as np
import pandas as pd
import yfinance as yf
from utils.finanzas import valor_por_multiplo_ev, per_justificado

OBJETIVO = ""       # tu empresa
COMPARABLES = []    # 4 a 6 tickers, criterios declarados arriba

# TU CODIGO AQUI: panel de datos y tabla de multiplos con mediana

# %% [markdown]
# ## Parte 2: valoración implícita (4 pts)
#
# Aplica la mediana EV/EBITDA al EBITDA de tu empresa, cruza el puente (deuda neta) y llega al valor por acción. Repite con el P/E. Compara ambos contra el precio de mercado. Si aplicas algún ajuste discrecional (descuento por tamaño o liquidez), decláralo y justifícalo en una oración.

# %%
# TU CODIGO AQUI: valor por accion por EV/EBITDA y por P/E, contra el precio

# %% [markdown]
# ## Parte 3: el múltiplo justificado (3 pts)
#
# Calcula el P/E justificado de tu empresa con tu Ke (tarea 2) y tu g perpetuo (tarea 4), usando el payout sobre capacidad de pago (FCFE/NI de tu tarea 3; si tu FCFE fue negativo, usa el payout de dividendos y coméntalo). Compara contra el P/E observado y comenta en una o dos oraciones.

# %%
# TU CODIGO AQUI: P/E justificado vs observado

# %% [markdown]
# ## Parte 4: la triangulación (4 pts)
#
# El gráfico final de la unidad: tus valores por acción por DCF Gordon, DCF con múltiplo de salida (tarea 4), comparables EV/EBITDA y comparables P/E (hoy), contra el precio de mercado. Cierra con un párrafo: ¿dónde cae el precio dentro del rango?, ¿intrínseco y relativo apuntan igual?, ¿cuál es tu veredicto condicionado? Este párrafo es el borrador de tu resumen ejecutivo del TR1.

# %%
# TU CODIGO AQUI: grafico de triangulacion

# %% [markdown]
# ## Parte 5: ítems tipo CFA (2 pts, 0.5 c/u)
#
# **1.** El P/E pierde sentido como comparable cuando:
#
# A. la empresa tiene mucha caja. B. la utilidad neta es negativa o cercana a cero. C. la empresa no paga dividendos.
#
# **2.** El P/B es el múltiplo estándar para:
#
# A. empresas financieras. B. mineras. C. empresas de tecnología.
#
# **3.** En un panel de comparables, la mediana se prefiere al promedio porque:
#
# A. es más fácil de calcular. B. resiste los valores extremos. C. siempre es menor.
#
# **4.** Un P/E observado muy por encima del justificado por fundamentos sugiere, en primera instancia:
#
# A. que la acción está sobrevalorada o que el mercado espera más crecimiento del que asumiste. B. que la empresa es de alta calidad. C. un error en los estados financieros.
#
# **Respuestas:**
#
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
#
# **Recuerda:** `Kernel  Restart & Run All` antes de entregar, y luego:
#
# ```bash
# git add 05_multiplos_comparables/clase05_tarea.ipynb
# git commit -m "Tarea semana 5"
# git push
# ```
