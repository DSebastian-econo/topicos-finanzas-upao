# %% [markdown]
# # Semana 4: Tarea
#
# **El DCF de tu empresa, versión profesional** (la misma empresa de las semanas 2 y 3)
#
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JonathanRosasV/topicos-finanzas-upao/blob/main/04_valor_terminal_ev/clase04_tarea.ipynb)
#
# **Entrega: hasta el lunes de la semana siguiente, vía `git commit` + `push` en tu fork** (`04_valor_terminal_ev/clase04_tarea.ipynb`)
#
# Total: 20 puntos (18 de contenido y 2 de forma: el notebook corre de inicio a fin y la entrega llega a tiempo). Esta tarea es el ensayo general del TR1.

# %% [markdown]
# ## Parte 1: valor terminal por dos métodos (4 pts)
#
# Partiendo de tu proyección de la tarea 3: calcula el VT por perpetuidad (con tu g declarado) y por múltiplo de salida EV/EBITDA (declara el múltiplo y da una razón de por qué es razonable para tu sector). Reporta el múltiplo implícito de tu Gordon y comenta en una oración si es coherente con el declarado.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
import numpy as np
import pandas as pd
import yfinance as yf
from utils.finanzas import (valor_terminal, valor_terminal_multiplo, dcf_dos_etapas,
                            fcff_desde_ebit, capm, wacc)

TICKER = ""   # tu empresa

# TU CODIGO AQUI: recupera tu proyeccion de la tarea 3 y calcula los dos VT

# %% [markdown]
# ## Parte 2: EV y puente completo al equity (4 pts)
#
# Para cada método de VT: EV, equity (restando deuda neta: deuda menos caja) y valor por acción, comparado contra el precio de mercado. Presenta los dos resultados en una tabla.

# %%
# TU CODIGO AQUI: EV, puente y valor por accion para ambos metodos

# %% [markdown]
# ## Parte 3: tabla de sensibilidad (4 pts)
#
# Construye la tabla de valor por acción para al menos 4 valores de WACC (alrededor del tuyo) y 4 valores de g perpetuo (todos defendibles: ninguno mayor que el crecimiento nominal de la economía relevante). Preséntala como tabla y como mapa de calor.

# %%
# TU CODIGO AQUI: tabla de sensibilidad y mapa de calor

# %% [markdown]
# ## Parte 4: veredicto en rango (2 pts)
#
# En un párrafo: ¿en qué fracción de tus escenarios la acción aparece subvaluada? ¿Cuál es tu rango de valor por acción y dónde cae el precio de mercado dentro de él? Cierra con una recomendación condicionada (por ejemplo: atractiva salvo que el WACC supere tal nivel).

# %% [markdown]
# ## Parte 5: ítems tipo CFA (4 pts, 1 c/u)
#
# **1.** En un DCF de dos etapas a 5 años, el valor terminal correcto en el año 5 usa:
#
# A. el FCFF del año 5. B. el FCFF del año 6. C. el promedio de los FCFF proyectados.
#
# **2.** Una empresa tiene capitalización 800, deuda 300, caja 100 y no tiene preferentes ni minoritarios. Su EV es:
#
# A. 1,000. B. 1,100. C. 1,200.
#
# **3.** Todo lo demás constante, un múltiplo de salida igual al múltiplo actual de una empresa en fuerte crecimiento tiende a:
#
# A. subestimar el VT, porque la empresa será más grande. B. sobreestimar el VT, porque en la madurez los múltiplos se comprimen. C. no genera sesgo alguno.
#
# **4.** El peso típico del valor terminal en el valor total de un DCF de dos etapas hace que la prioridad del analista sea:
#
# A. afinar la proyección explícita del año 1. B. escrutar los supuestos de la perpetuidad y reportar sensibilidad. C. extender el horizonte a 20 años para eliminar el VT.
#
# **Respuestas:**
#
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
#
# **Recuerda:** `Kernel  Restart & Run All` antes de entregar, y luego:
#
# ```bash
# git add 04_valor_terminal_ev/clase04_tarea.ipynb
# git commit -m "Tarea semana 4"
# git push
# ```
